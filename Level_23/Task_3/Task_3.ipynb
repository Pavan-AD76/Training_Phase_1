# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/nithy/OneDrive/Desktop/Training/Level_22/TASK 3/SOLUTION.csv")

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['Year'], df['Cellphones_per_person'], marker='o', linestyle='-', color='blue')
plt.title('Rise of Cell Phones Over Time')
plt.xlabel('Year')
plt.ylabel('Average Cell Phones per Person')
plt.grid(True)
plt.tight_layout()
plt.show()
