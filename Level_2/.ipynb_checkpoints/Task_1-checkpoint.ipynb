# %% [markdown]
# ## Task 1: Simple Plot

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=[1,2,3]
y=[2,4,6]
plt.plot(x,y,marker='o')
plt.title('Line chart')
plt.xlabel('X value')
plt.ylabel('Y value')
plt.show()
